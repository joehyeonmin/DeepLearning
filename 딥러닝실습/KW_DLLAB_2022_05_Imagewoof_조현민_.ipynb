# %% [markdown]
# # ResNet 50으로 Imagewoof 분류해보기<br>
# by uramoon@kw.ac.kr
#
# 이 저작물은 <a href="https://creativecommons.org/licenses/by-nc-sa/2.0/kr/">CC BY-NC-SA 2.0 KR</a>에 따라 이용할 수 있습니다. (단, 라이선스가 명시된 일부 문서 및 삽화 제외)<br>
# 기여하신 문서의 저작권은 각 기여자에게 있으며, 각 기여자는 기여하신 부분의 저작권을 갖습니다.<br>
# Imagewoof 출처 : https://github.com/fastai/imagenette

# %% [markdown]
# ## Imagewoof 중 일부만 압축 풀기<br>
# 자료실에서 KW_Imagewoof를 다운받아 Colab에 복사한 후 진행하세요.

# %%
# !unzip -q KW_imagewoof2-320.zip

# %% [markdown]
# ## 클래스 인덱스와 이름 알아보기<br>
# KW_imagewoof2-320/n0.. 폴더에는 각 클래스에 해당하는 사진이 있습니다.<br>
# (왼쪽 파일 목록을 새로고침하고 KW_imagewoof2-320 폴더를 확인해보세요.)<br><br>
# ImageNet은 1,000 개의 클래스를 갖고 있는데 n0..이
# 1. ImageNet에서 몇 번째 클래스에 해당하는지
# 2. 사람이 식별하기 위한 이름은 어떻게 되는지 살펴봅시다.<br>
# (imagenet_class_index.json 파일 활용)<br>
# 출처: https://github.com/raghakot/keras-vis/blob/master/resources/imagenet_class_index.json

# %%
# 0번째 클래스는 n01440764인 잉어, 1번째 클래스는 n01443537인 금붕어, ...
# !head imagenet_class_index.json
# Out:
# {"0": ["n01440764", "tench"], "1": ["n01443537", "goldfish"], "2": ["n01484850", "great_white_shark"], "3": ["n01491361", "tiger_shark"], "4": ["n01494475", "hammerhead"], "5": ["n01496331", "electric_ray"], "6": ["n01498041", "stingray"], "7": ["n01514668", "cock"], "8": ["n01514859", "hen"], "9": ["n01518878", "ostrich"], "10": ["n01530575", "brambling"], "11": ["n01531178", "goldfinch"], "12": ["n01532829", "house_finch"], "13": ["n01534433", "junco"], "14": ["n01537544", "indigo_bunting"], "15": ["n01558993", "robin"], "16": ["n01560419", "bulbul"], "17": ["n01580077", "jay"], "18": ["n01582220", "magpie"], "19": ["n01592084", "chickadee"], "20": ["n01601694", "water_ouzel"], "21": ["n01608432", "kite"], "22": ["n01614925", "bald_eagle"], "23": ["n01616318", "vulture"], "24": ["n01622779", "great_grey_owl"], "25": ["n01629819", "European_fire_salamander"], "26": ["n01630670", "common_newt"], "27": ["n01631663", "eft"], "28": ["n01632458", "spotted_salamander"], "29": ["n01632777", "axolotl"], "30": ["n01641577", "bullfrog"], "31": ["n01644373", "tree_frog"], "32": ["n01644900", "tailed_frog"], "33": ["n01664065", "loggerhead"], "34": ["n01665541", "leatherback_turtle"], "35": ["n01667114", "mud_turtle"], "36": ["n01667778", "terrapin"], "37": ["n01669191", "box_turtle"], "38": ["n01675722", "banded_gecko"], "39": ["n01677366", "common_iguana"], "40": ["n01682714", "American_chameleon"], "41": ["n01685808", "whiptail"], "42": ["n01687978", "agama"], "43": ["n01688243", "frilled_lizard"], "44": ["n01689811", "alligator_lizard"], "45": ["n01692333", "Gila_monster"], "46": ["n01693334", "green_lizard"], "47": ["n01694178", "African_chameleon"], "48": ["n01695060", "Komodo_dragon"], "49": ["n01697457", "African_crocodile"], "50": ["n01698640", "American_alligator"], "51": ["n01704323", "triceratops"], "52": ["n01728572", "thunder_snake"], "53": ["n01728920", "ringneck_snake"], "54": ["n01729322", "hognose_snake"], "55": ["n01729977", "green_snake"], "56": ["n01734418", "king_snake"], "57": ["n01735189", "garter_snake"], "58": ["n01737021", "water_snake"], "59": ["n01739381", "vine_snake"], "60": ["n01740131", "night_snake"], "61": ["n01742172", "boa_constrictor"], "62": ["n01744401", "rock_python"], "63": ["n01748264", "Indian_cobra"], "64": ["n01749939", "green_mamba"], "65": ["n01751748", "sea_snake"], "66": ["n01753488", "horned_viper"], "67": ["n01755581", "diamondback"], "68": ["n01756291", "sidewinder"], "69": ["n01768244", "trilobite"], "70": ["n01770081", "harvestman"], "71": ["n01770393", "scorpion"], "72": ["n01773157", "black_and_gold_garden_spider"], "73": ["n01773549", "barn_spider"], "74": ["n01773797", "garden_spider"], "75": ["n01774384", "black_widow"], "76": ["n01774750", "tarantula"], "77": ["n01775062", "wolf_spider"], "78": ["n01776313", "tick"], "79": ["n01784675", "centipede"], "80": ["n01795545", "black_grouse"], "81": ["n01796340", "ptarmigan"], "82": ["n01797886", "ruffed_grouse"], "83": ["n01798484", "prairie_chicken"], "84": ["n01806143", "peacock"], "85": ["n01806567", "quail"], "86": ["n01807496", "partridge"], "87": ["n01817953", "African_grey"], "88": ["n01818515", "macaw"], "89": ["n01819313", "sulphur-crested_cockatoo"], "90": ["n01820546", "lorikeet"], "91": ["n01824575", "coucal"], "92": ["n01828970", "bee_eater"], "93": ["n01829413", "hornbill"], "94": ["n01833805", "hummingbird"], "95": ["n01843065", "jacamar"], "96": ["n01843383", "toucan"], "97": ["n01847000", "drake"], "98": ["n01855032", "red-breasted_merganser"], "99": ["n01855672", "goose"], "100": ["n01860187", "black_swan"], "101": ["n01871265", "tusker"], "102": ["n01872401", "echidna"], "103": ["n01873310", "platypus"], "104": ["n01877812", "wallaby"], "105": ["n01882714", "koala"], "106": ["n01883070", "wombat"], "107": ["n01910747", "jellyfish"], "108": ["n01914609", "sea_anemone"], "109": ["n01917289", "brain_coral"], "110": ["n01924916", "flatworm"], "111": ["n01930112", "nematode"], "112": ["n01943899", "conch"], "113": ["n01 ...

# %%
import json
idx2label = []  # 인덱스를 입력하면 사람이 이해할 수 있는 이름표가 나옵니다.
cls2label = {}  # 'n02086240' 같은 것을 입력하면 사람이 이해할 수 있는 이름표가 나옵니다.
cls2idx = {}    # 'n02086240' 같은 것을 입력하면 인덱스가 나옵니다. [0, 999]: 인공신경망의 몇 번째 출력에 해당하는가

with open("imagenet_class_index.json", "r") as read_file:
    class_idx = json.load(read_file)
    idx2label = [class_idx[str(k)][1] for k in range(len(class_idx))]
    cls2label = {class_idx[str(k)][0]: class_idx[str(k)][1] for k in range(len(class_idx))}
    cls2idx = {class_idx[str(k)][0]: k for k in range(len(class_idx))}

# %%
print(idx2label)
print(cls2label.get("n02086240"))
print(cls2idx.get("n02086240"))
# Out:
# ['tench', 'goldfish', 'great_white_shark', 'tiger_shark', 'hammerhead', 'electric_ray', 'stingray', 'cock', 'hen', 'ostrich', 'brambling', 'goldfinch', 'house_finch', 'junco', 'indigo_bunting', 'robin', 'bulbul', 'jay', 'magpie', 'chickadee', 'water_ouzel', 'kite', 'bald_eagle', 'vulture', 'great_grey_owl', 'European_fire_salamander', 'common_newt', 'eft', 'spotted_salamander', 'axolotl', 'bullfrog', 'tree_frog', 'tailed_frog', 'loggerhead', 'leatherback_turtle', 'mud_turtle', 'terrapin', 'box_turtle', 'banded_gecko', 'common_iguana', 'American_chameleon', 'whiptail', 'agama', 'frilled_lizard', 'alligator_lizard', 'Gila_monster', 'green_lizard', 'African_chameleon', 'Komodo_dragon', 'African_crocodile', 'American_alligator', 'triceratops', 'thunder_snake', 'ringneck_snake', 'hognose_snake', 'green_snake', 'king_snake', 'garter_snake', 'water_snake', 'vine_snake', 'night_snake', 'boa_constrictor', 'rock_python', 'Indian_cobra', 'green_mamba', 'sea_snake', 'horned_viper', 'diamondback', 'sidewinder', 'trilobite', 'harvestman', 'scorpion', 'black_and_gold_garden_spider', 'barn_spider', 'garden_spider', 'black_widow', 'tarantula', 'wolf_spider', 'tick', 'centipede', 'black_grouse', 'ptarmigan', 'ruffed_grouse', 'prairie_chicken', 'peacock', 'quail', 'partridge', 'African_grey', 'macaw', 'sulphur-crested_cockatoo', 'lorikeet', 'coucal', 'bee_eater', 'hornbill', 'hummingbird', 'jacamar', 'toucan', 'drake', 'red-breasted_merganser', 'goose', 'black_swan', 'tusker', 'echidna', 'platypus', 'wallaby', 'koala', 'wombat', 'jellyfish', 'sea_anemone', 'brain_coral', 'flatworm', 'nematode', 'conch', 'snail', 'slug', 'sea_slug', 'chiton', 'chambered_nautilus', 'Dungeness_crab', 'rock_crab', 'fiddler_crab', 'king_crab', 'American_lobster', 'spiny_lobster', 'crayfish', 'hermit_crab', 'isopod', 'white_stork', 'black_stork', 'spoonbill', 'flamingo', 'little_blue_heron', 'American_egret', 'bittern', 'crane', 'limpkin', 'European_gallinule', 'American_coot', 'bustard', 'ruddy_turnstone', 'red-backed_sandpiper', 'redshank', 'dowitcher', 'oystercatcher', 'pelican', 'king_penguin', 'albatross', 'grey_whale', 'killer_whale', 'dugong', 'sea_lion', 'Chihuahua', 'Japanese_spaniel', 'Maltese_dog', 'Pekinese', 'Shih-Tzu', 'Blenheim_spaniel', 'papillon', 'toy_terrier', 'Rhodesian_ridgeback', 'Afghan_hound', 'basset', 'beagle', 'bloodhound', 'bluetick', 'black-and-tan_coonhound', 'Walker_hound', 'English_foxhound', 'redbone', 'borzoi', 'Irish_wolfhound', 'Italian_greyhound', 'whippet', 'Ibizan_hound', 'Norwegian_elkhound', 'otterhound', 'Saluki', 'Scottish_deerhound', 'Weimaraner', 'Staffordshire_bullterrier', 'American_Staffordshire_terrier', 'Bedlington_terrier', 'Border_terrier', 'Kerry_blue_terrier', 'Irish_terrier', 'Norfolk_terrier', 'Norwich_terrier', 'Yorkshire_terrier', 'wire-haired_fox_terrier', 'Lakeland_terrier', 'Sealyham_terrier', 'Airedale', 'cairn', 'Australian_terrier', 'Dandie_Dinmont', 'Boston_bull', 'miniature_schnauzer', 'giant_schnauzer', 'standard_schnauzer', 'Scotch_terrier', 'Tibetan_terrier', 'silky_terrier', 'soft-coated_wheaten_terrier', 'West_Highland_white_terrier', 'Lhasa', 'flat-coated_retriever', 'curly-coated_retriever', 'golden_retriever', 'Labrador_retriever', 'Chesapeake_Bay_retriever', 'German_short-haired_pointer', 'vizsla', 'English_setter', 'Irish_setter', 'Gordon_setter', 'Brittany_spaniel', 'clumber', 'English_springer', 'Welsh_springer_spaniel', 'cocker_spaniel', 'Sussex_spaniel', 'Irish_water_spaniel', 'kuvasz', 'schipperke', 'groenendael', 'malinois', 'briard', 'kelpie', 'komondor', 'Old_English_sheepdog', 'Shetland_sheepdog', 'collie', 'Border_collie', 'Bouvier_des_Flandres', 'Rottweiler', 'German_shepherd', 'Doberman', 'miniature_pinscher', 'Greater_Swiss_Mountain_dog', 'Bernese_mountain_dog', 'Appenzeller', 'EntleBucher', 'boxer', 'bull_mastiff', 'Tibetan_mastiff', 'French_bulldog', 'Great_Dane', 'Saint_Bernard', 'Eskimo_dog', 'malamute', 'Siberian_husky', 'dalmatian', 'affenpinscher', 'basenji', 'pug', 'Leonbe ...
# Shih-Tzu
# 155

# %% [markdown]
# ## TODO1: 딕셔너리 활용하기<br>
# 아래의 두 개를 출력해보세요.
#
# 1. n02086240은 몇 번째 클래스인가? 인덱스를 출력하세요. (모델의 출력에서 사용)
# 2. n02086240의 클래스 이름은 무엇인가? (인간이 식별하기 편한 이름)

# %%
target = 'n02086240'
print(idx2label[155])
print(cls2label.get(target))
print(cls2idx.get(target))

# n02086240의 index : 155
# n02086240의 클래스 이름 : Shih-Tzu
# Out:
# Shih-Tzu
# Shih-Tzu
# 155

# %% [markdown]
# ## TODO2: 각 디렉토리에서 무작위로 5개씩 그려봅시다.<br>
# 총 10종의 개 이미지가 있으니 50장이 그려집니다.<br>
# TODO 표시된 두 줄만 작성하시면 됩니다.

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

# KW_imagewoof2-320 하위 폴더 가져오기
subfolders = [f.path for f in os.scandir('KW_imagewoof2-320') if f.is_dir()]

idx = 1
plt.figure(figsize=(25, 25))
# 각 디렉토리에서
for dir in subfolders:  
  # JPEG 파일을 5개씩 무작위로 그리기
  for i in range(5):    
    plt.subplot(10, 5, idx)
    idx = idx + 1
    rand_file = random.choice(os.listdir(dir))# TODO: 기존 노트북 참조
    img = mpimg.imread(dir + '/' + rand_file)
    # 각 그림의 제목에 클래스 이름과 그림 사이즈를 출력하세요. (예: golden_triever (높이, 너비, 채널))
    # Hint: 딕셔너리와 img.shape 활용
    name = cls2label.get(dir[-9:]) + str(img.shape)
    # shape = 
    plt.title(name) # TODO: 괄호에 문자열을 넣으면 제목으로 들어감
    plt.imshow(img) 
plt.subplots_adjust(hspace=0.5)    
plt.show()

# %% [markdown]
# ## TODO3: JPEG을 224 x 224 크기의 PIL (Python Imaging Library) 이미지로 변환<br>
# 우리가 사용할 ResNet50은 224 x 224를 입력으로 받습니다.
# 1. JPEG 그려보기

# %%
# 다음 임의의 JPEG 이미지를 그려보세요.
fname = 'KW_imagewoof2-320/n02089973/ILSVRC2012_val_00003671.JPEG'
plt.imshow(mpimg.imread(fname))

# %% [markdown]
# 2. JPEG을 224 x 224 크기의 PIL image로 변환하기<br>
# Hint: https://keras.io/api/preprocessing/image/ 에서 load_img 함수 사용

# %%
from keras.preprocessing import image

# 상기 JPEG 파일 변환해보기
img_data = image.load_img(fname, target_size = (224,224)) 

# img_data 그려보기
plt.imshow(img_data)  # TODO: 쉽습니다. 괄호안에 이미지 객체를 넣으세요.

# %% [markdown]
# ## TODO4: PIL 이미지를 NumPy로 변환하기<br>
# Hint: https://keras.io/api/preprocessing/image/ 에서 img_to_array 함수 사용 <br>
# 컬러 이미지의 채널이 몇 개인지 shape를 확인해보세요.

# %%
# NumPy array로 변환 후 shape 확인하기
import tensorflow as tf

# img_to_array -> numpy array로 변환해줌
array = tf.keras.preprocessing.image.img_to_array(img_data)
array.shape
# Out:
# (320, 426, 3)

# %% [markdown]
# ## TODO5: NumPy array 각 채널 그려보기<br>
# 채널에 따라 적절한 컬러맵을 선택하세요.<br>
# https://matplotlib.org/3.5.1/tutorials/colors/colormaps.html

# %%
r_img = array[:, :, -3] # TODO: 첫 번째 채널
g_img = array[:, :, -2] # TODO: 두 번째 채널
b_img = array[:, :, -1] # TODO: 세 번째 채널

f, axarr = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))
plt.sca(axarr[0])
plt.imshow(r_img, cmap='Reds')  # TODO: 첫 번째 채널
plt.sca(axarr[1])
plt.imshow(g_img, cmap='Greens')  # TODO: 두 번째 채널
plt.sca(axarr[2])
plt.imshow(b_img, cmap='Blues')  # TODO: 세 번째 채널

# %% [markdown]
# ## TODO6: 테스트 데이터 만들기<br>
# KW_imagewoff2-320 폴더 아래에 있는 모든 이미지에 대해 이미지에 해당하는 NumPy 배열과 인덱스로 구성된 레이블을 만들어야 합니다.<br>
# 뼈대 코드를 무시하고 자유롭게 만드셔도 됩니다.<br>
# 예) test_images, test_labels

# %%
# 'KW_imagewoof2-320/n02089973/ILSVRC2012_val_00003671.JPEG'
print(tmp)
# Out:
# KW_imagewoof2-320/n02096294/ILSVRC2012_val_00017380.JPEG

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

test_images = []
test_labels = []

# KW_imagewoof2-320 하위 폴더 가져오기
subfolders = [f.path for f in os.scandir('KW_imagewoof2-320') if f.is_dir()]
# TODO: 위에서 수행한 적 있습니다.

# 각 디렉토리에서
for dir in subfolders:  
  for fname in os.listdir(dir):
    # load_img를 이용해 224 x 224 PIL 이미지로 읽어오세요.
    tmp = dir + '/' + fname
    img = image.load_img(tmp, target_size = (224,224)) 
    # PIL 이미지를 NumPy 배열로 변환합니다.
    x = array = tf.keras.preprocessing.image.img_to_array(img)
    # ResNet50에서 제공하는 입력 전처리 (별도로 정규화하지 마세요.)
    x = preprocess_input(x)  
    test_images.append(x) # 그림 하나 추가
    test_labels.append(cls2idx.get(dir[-9:])) # 정답 하나 추가 (몇 번째 클래스인지 인덱스로 추가해야 함)
   
test_images = np.asarray(test_images)
test_labels = np.asarray(test_labels)

# %%
# Q: 다음이 의미하는 바는?
# A: 162개 이미지가 (224 x 224) 형태로 rgb(3채널) 형태로 들어있다.
print(test_images.shape)
print(test_labels.shape)
# Out:
# (162, 224, 224, 3)
# (162,)

# %% [markdown]
# ## ResNet50 불러오기

# %%
import numpy as np

# 불러오기
model = ResNet50(weights='imagenet')

# 예측하기
preds = model.predict(test_images)

# %% [markdown]
# ## TODO7: 예측 결과 살펴보기<br>
# 실제의 레이블과 TOP-3 레이블을 비교해보세요.<br>
# Hint: https://www.tensorflow.org/api_docs/python/tf/keras/applications/imagenet_utils/decode_predictions

# %%
decodes = decode_predictions(preds, top=3 ) # TODO

for i in range(len(preds)):
  print('Actual:', idx2label[test_labels[i]], 'Predicted:', decodes[i]) # TODO: i 번째 이미지의 실제 레이블을 출력해보세요.
# Out:
# Actual: Rhodesian_ridgeback Predicted: [('n02087394', 'Rhodesian_ridgeback', 0.9837022), ('n02109047', 'Great_Dane', 0.014217023), ('n02090379', 'redbone', 0.0010164862)]
# Actual: Rhodesian_ridgeback Predicted: [('n02087394', 'Rhodesian_ridgeback', 0.9728267), ('n02090379', 'redbone', 0.010227662), ('n02093428', 'American_Staffordshire_terrier', 0.010209058)]
# Actual: Rhodesian_ridgeback Predicted: [('n02087394', 'Rhodesian_ridgeback', 0.6753373), ('n02109047', 'Great_Dane', 0.10843561), ('n02108089', 'boxer', 0.075631194)]
# Actual: Rhodesian_ridgeback Predicted: [('n02087394', 'Rhodesian_ridgeback', 0.831966), ('n02088466', 'bloodhound', 0.07943911), ('n02090379', 'redbone', 0.04085012)]
# Actual: Rhodesian_ridgeback Predicted: [('n02090379', 'redbone', 0.6812373), ('n02088466', 'bloodhound', 0.28763542), ('n02087394', 'Rhodesian_ridgeback', 0.028580924)]
# Actual: Rhodesian_ridgeback Predicted: [('n02100583', 'vizsla', 0.8010034), ('n02099712', 'Labrador_retriever', 0.047115088), ('n02087394', 'Rhodesian_ridgeback', 0.042698488)]
# Actual: Rhodesian_ridgeback Predicted: [('n02087394', 'Rhodesian_ridgeback', 0.9960653), ('n02099712', 'Labrador_retriever', 0.0011182461), ('n02108422', 'bull_mastiff', 0.0011061841)]
# Actual: Rhodesian_ridgeback Predicted: [('n02087394', 'Rhodesian_ridgeback', 0.5226701), ('n02109047', 'Great_Dane', 0.3971387), ('n02105162', 'malinois', 0.028297372)]
# Actual: Rhodesian_ridgeback Predicted: [('n02088466', 'bloodhound', 0.62580085), ('n02090379', 'redbone', 0.26503333), ('n02100583', 'vizsla', 0.056966204)]
# Actual: Rhodesian_ridgeback Predicted: [('n02087394', 'Rhodesian_ridgeback', 0.45864457), ('n02099849', 'Chesapeake_Bay_retriever', 0.34930927), ('n02090379', 'redbone', 0.124620624)]
# Actual: Rhodesian_ridgeback Predicted: [('n02087394', 'Rhodesian_ridgeback', 0.83093303), ('n02090379', 'redbone', 0.047928836), ('n02100583', 'vizsla', 0.04587568)]
# Actual: Rhodesian_ridgeback Predicted: [('n02108089', 'boxer', 0.34264252), ('n02087394', 'Rhodesian_ridgeback', 0.25877905), ('n02093428', 'American_Staffordshire_terrier', 0.24046877)]
# Actual: Rhodesian_ridgeback Predicted: [('n02090379', 'redbone', 0.50102717), ('n02087394', 'Rhodesian_ridgeback', 0.31880227), ('n02100583', 'vizsla', 0.10687432)]
# Actual: Rhodesian_ridgeback Predicted: [('n02087394', 'Rhodesian_ridgeback', 0.9519031), ('n02109047', 'Great_Dane', 0.030991204), ('n02090379', 'redbone', 0.0069571612)]
# Actual: Rhodesian_ridgeback Predicted: [('n02087394', 'Rhodesian_ridgeback', 0.36699584), ('n02093428', 'American_Staffordshire_terrier', 0.17300147), ('n02100583', 'vizsla', 0.12798612)]
# Actual: English_foxhound Predicted: [('n02088238', 'basset', 0.8299965), ('n02089867', 'Walker_hound', 0.100493625), ('n02088466', 'bloodhound', 0.0377526)]
# Actual: English_foxhound Predicted: [('n02089973', 'English_foxhound', 0.69585294), ('n02089867', 'Walker_hound', 0.30284974), ('n02088364', 'beagle', 0.0007507861)]
# Actual: English_foxhound Predicted: [('n02089867', 'Walker_hound', 0.5173735), ('n02089973', 'English_foxhound', 0.2519374), ('n02095314', 'wire-haired_fox_terrier', 0.074881196)]
# Actual: English_foxhound Predicted: [('n02090379', 'redbone', 0.8434783), ('n02099601', 'golden_retriever', 0.044481706), ('n02088466', 'bloodhound', 0.01881641)]
# Actual: English_foxhound Predicted: [('n02089867', 'Walker_hound', 0.8050748), ('n02089973', 'English_foxhound', 0.18013602), ('n02088364', 'beagle', 0.01361149)]
# Actual: English_foxhound Predicted: [('n02089867', 'Walker_hound', 0.7151334), ('n02089973', 'English_foxhound', 0.23828745), ('n02088632', 'bluetick', 0.014950728)]
# Actual: English_foxhound Predicted: [('n02089973', 'English_foxhound', 0.931025), ('n02091244', 'Ibizan_hound', 0.012672207), ('n02092339', 'Weimaraner', 0.011138777)]
# Actual: English_foxhound Predicted: [('n02088364', 'beagle', 0.22283186), ('n02113186', 'Cardigan', 0.10836204), ('n02093256', 'Staffordshire_bullterrier', 0.108174846)]
# Actual: English_foxhound Predicted: [('n02088238', 'basset', 0.6525534), ('n04557648', 'water_bottle', 0.03481853), ('n02909870', 'bucket', 0.025484229)]
# Actual: English_foxhound Predicted: [('n02089973', 'English_foxhound', 0.59487563), ('n02089867', 'Walker_hound', 0.37600866), ('n02088364', 'beagle', 0.015008551)]
# Actual: English_foxhound Predicted: [('n02089973', 'English_foxhound', 0.34236425), ('n02088238', 'basset', 0.26216555), ('n02088364', 'beagle', 0.22235021)]
# Actual: English_foxhound Predicted: [('n02090622', 'borzoi', 0.5975111), ('n02100735', 'English_setter', 0.11130166), ('n02101388', 'Brittany_spaniel', 0.06493432)]
# Actual: English_foxhound Predicted: [('n02091244', 'Ibizan_hound', 0.21306399), ('n02089867', 'Walker_hound', 0.17769918), ('n02089973', 'English_foxhound', 0.16537863)]
# Actual: golden_retriever Predicted: [('n02099601', 'golden_retriever', 0.9067836), ('n02104029', 'kuvasz', 0.059637822), ('n02111500', 'Great_Pyrenees', 0.017411016)]
# Actual: golden_retriever Predicted: [('n02109525', 'Saint_Bernard', 0.21962261), ('n02107683', 'Bernese_mountain_dog', 0.21488705), ('n02111277', 'Newfoundland', 0.15597476)]
# Actual: golden_retriever Predicted: [('n02099601', 'golden_retriever', 0.58962375), ('n02093991', 'Irish_terrier', 0.25711438), ('n02094114', 'Norfolk_terrier', 0.040596712)]
# Actual: golden_retriever Predicted: [('n02099601', 'golden_retriever', 0.5378866), ('n02104029', 'kuvasz', 0.14425795), ('n02111129', 'Leonberg', 0.07273578)]
# Actual: golden_retriever Predicted: [('n02099601', 'golden_retriever', 0.95534694), ('n02100877', 'Irish_setter', 0.013700774), ('n02093991', 'Irish_terrier', 0.0048938342)]
# Actual: golden_retriever Predicted: [('n02086646', 'Blenheim_spaniel', 0.50714415), ('n02102480', 'Sussex_spaniel', 0.24237923), ('n02102318', 'cocker_spaniel', 0.13283756)]
# Actual: golden_retriever Predicted: [('n02099601', 'golden_retriever', 0.99906665), ('n02099712', 'Labrador_retriever', 0.00051937794), ('n02102318', 'cocker_spaniel', 7.137385e-05)]
# Actual: golden_retriever Predicted: [('n02099601', 'golden_retriever', 0.9741682), ('n02099712', 'Labrador_retriever', 0.013719041), ('n02104029', 'kuvasz', 0.0045570815)]
# Actual: golden_retriever Predicted: [('n02099601', 'golden_retriever', 0.9381433), ('n02102318', 'cocker_spaniel', 0.010975476), ('n02100877', 'Irish_setter', 0.005496184)]
# Actual: golden_retriever Predicted: [('n02099601', 'golden_retriever', 0.5889612), ('n02094114', 'Norfolk_terrier', 0.13876723), ('n02099712', 'Labrador_retriever', 0.109130085)]
# Actual: golden_retriever Predicted: [('n02094114', 'Norfolk_terrier', 0.5055621), ('n02099601', 'golden_retriever', 0.42193463), ('n02112137', 'chow', 0.020927485)]
# Actual: golden_retriever Predicted: [('n02099601', 'golden_retriever', 0.5726287), ('n02091831', 'Saluki', 0.2434988), ('n02088094', 'Afghan_hound', 0.1277097)]
# Actual: golden_retriever Predicted: [('n02099601', 'golden_retriever', 0.87457573), ('n02099712', 'Labrador_retriever', 0.10432097), ('n02104029', 'kuvasz', 0.018725192)]
# Actual: golden_retriever Predicted: [('n02104029', 'kuvasz', 0.4140308), ('n02099601', 'golden_retriever', 0.2655656), ('n02090622', 'borzoi', 0.24933973)]
# Actual: golden_retriever Predicted: [('n02099712', 'Labrador_retriever', 0.4151451), ('n02109961', 'Eskimo_dog', 0.15082651), ('n02110185', 'Siberian_husky', 0.11777351)]
# Actual: golden_retriever Predicted: [('n02099601', 'golden_retriever', 0.9879265), ('n02099712', 'Labrador_retriever', 0.009883175), ('n02099267', 'flat-coated_retriever', 0.00044927458)]
# Actual: golden_retriever Predicted: [('n02099601', 'golden_retriever', 0.61084116), ('n02090721', 'Irish_wolfhound', 0.1874053), ('n02111500', 'Great_Pyrenees', 0.073817775)]
# Actual: golden_retriever Predicted: [('n02099601', 'golden_retriever', 0.8094226), ('n02091831', 'Saluki', 0.069101624), ('n02111500', 'Great_Pyrenees', 0.03343474)]
# Actual: Border_terrier Predicted: [('n02097047', 'miniature_schnauzer', 0.7273092), ('n02097209', 'standard_schnauzer', 0.052235886), ('n02096051', 'Airedale', 0.050012335)]
# Actual: Border_terrier Predicted: [('n02094258', 'Norwich_terrier', 0.31001973), ('n02096177', 'cairn', 0.23055963), ('n02093754', 'Border_terrier', 0.18632299)]
# Actual: Border_terrier Predicted: [('n02093754', 'Border_terrier', 0.42447004), ('n02106662', 'German_shepherd', 0.051605016), ('n02102318', 'cocker_spaniel', 0.05062105)]
# Actual: Border_terrier Predicted: [('n02112137', 'chow', 0.20810539), ('n02086079', 'Pekinese', 0.16937882), ('n02123394', 'Persian_cat', 0.091768615)]
# Actual: Border_terrier Predicted: [('n02093754', 'Border_terrier', 0.9998215), ('n02098105', 'soft-coated_wheaten_terrier', 0.00010566605), ('n02096177', 'cairn', 3.8529088e-05)]
# Actual: Border_terrier Predicted: [('n02093754', 'Border_terrier', 0.74690485), ('n03590841', "jack-o'-lantern", 0.15972789), ('n02108422', 'bull_mastiff', 0.018374918)]
# Actual: Border_terrier Predicted: [('n02108422', 'bull_mastiff', 0.41883346), ('n02108089', 'boxer', 0.12910597), ('n02088466', 'bloodhound', 0.12293066)]
# Actual: Border_terrier Predicted: [('n02093754', 'Border_terrier', 0.42941058), ('n02098105', 'soft-coated_wheaten_terrier', 0.3270777), ('n02096177', 'cairn', 0.07929484)]
# Actual: Border_terrier Predicted: [('n02093754', 'Border_terrier', 0.9999902), ('n02096177', 'cairn', 6.9055336e-06), ('n02096437', 'Dandie_Dinmont', 4.605364e-07)]
# Actual: Border_terrier Predicted: [('n02093991', 'Irish_terrier', 0.619024), ('n02096177', 'cairn', 0.25861076), ('n02093754', 'Border_terrier', 0.03230448)]
# Actual: Border_terrier Predicted: [('n02096177', 'cairn', 0.38573563), ('n02105251', 'briard', 0.2747521), ('n02093754', 'Border_terrier', 0.11769648)]
# Actual: Border_terrier Predicted: [('n02093754', 'Border_terrier', 0.99950993), ('n02095570', 'Lakeland_terrier', 6.763776e-05), ('n02106662', 'German_shepherd', 5.478821e-05)]
# Actual: Border_terrier Predicted: [('n02093754', 'Border_terrier', 0.9521861), ('n02098105', 'soft-coated_wheaten_terrier', 0.033631958), ('n02096177', 'cairn', 0.0021557703)]
# Actual: Border_terrier Predicted: [('n02108422', 'bull_mastiff', 0.7004471), ('n02108089', 'boxer', 0.17306538), ('n02109047', 'Great_Dane', 0.10002624)]
# Actual: Border_terrier Predicted: [('n02093754', 'Border_terrier', 0.9956442), ('n02096177', 'cairn', 0.0030345079), ('n02098105', 'soft-coated_wheaten_terrier', 0.0003419201)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.5620849), ('n02104029', 'kuvasz', 0.24239518), ('n02111500', 'Great_Pyrenees', 0.13437907)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.8525651), ('n02113799', 'standard_poodle', 0.052992), ('n02111500', 'Great_Pyrenees', 0.04852692)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.9840965), ('n02111500', 'Great_Pyrenees', 0.0070876195), ('n02112137', 'chow', 0.0016370383)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.9743531), ('n02111500', 'Great_Pyrenees', 0.01995842), ('n02112137', 'chow', 0.0016226848)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.9504687), ('n02111500', 'Great_Pyrenees', 0.007346173), ('n02090622', 'borzoi', 0.006451901)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.9994399), ('n02112137', 'chow', 0.0002427415), ('n02112018', 'Pomeranian', 0.00016025256)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.8384337), ('n02111500', 'Great_Pyrenees', 0.13731296), ('n02114548', 'white_wolf', 0.022468677)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.99998283), ('n02104029', 'kuvasz', 1.0192268e-05), ('n02111500', 'Great_Pyrenees', 4.591746e-06)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.8963393), ('n02110063', 'malamute', 0.031122325), ('n02109961', 'Eskimo_dog', 0.02096746)]
# Actual: Samoyed Predicted: [('n02113799', 'standard_poodle', 0.86258954), ('n02111500', 'Great_Pyrenees', 0.10287583), ('n02113712', 'miniature_poodle', 0.013252602)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.9935203), ('n02104029', 'kuvasz', 0.0021604344), ('n02111500', 'Great_Pyrenees', 0.001556214)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.36915478), ('n02112137', 'chow', 0.21564645), ('n02111500', 'Great_Pyrenees', 0.12388637)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.8461841), ('n02104029', 'kuvasz', 0.042491328), ('n09428293', 'seashore', 0.03035734)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.99908054), ('n02114548', 'white_wolf', 0.00057969574), ('n02120079', 'Arctic_fox', 0.00015793562)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.98083514), ('n02114548', 'white_wolf', 0.01103196), ('n02134084', 'ice_bear', 0.0043801325)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.9525336), ('n02110185', 'Siberian_husky', 0.025095748), ('n02109961', 'Eskimo_dog', 0.018399917)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.99891603), ('n02114548', 'white_wolf', 0.0003958917), ('n02120079', 'Arctic_fox', 0.0002654122)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.95213866), ('n02106030', 'collie', 0.014612586), ('n02106166', 'Border_collie', 0.010376491)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.9938845), ('n02109961', 'Eskimo_dog', 0.0016804334), ('n02114548', 'white_wolf', 0.0011748613)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.99604946), ('n02104029', 'kuvasz', 0.002712641), ('n02111500', 'Great_Pyrenees', 0.0011156548)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.9243695), ('n02104029', 'kuvasz', 0.050822433), ('n02114548', 'white_wolf', 0.0050713327)]
# Actual: Samoyed Predicted: [('n02111889', 'Samoyed', 0.9918251), ('n02111500', 'Great_Pyrenees', 0.0054147164), ('n02104029', 'kuvasz', 0.0025977022)]
# Actual: beagle Predicted: [('n02107574', 'Greater_Swiss_Mountain_dog', 0.6657506), ('n02108000', 'EntleBucher', 0.1769354), ('n02088238', 'basset', 0.07072521)]
# Actual: beagle Predicted: [('n02088364', 'beagle', 0.5910242), ('n02089867', 'Walker_hound', 0.3564429), ('n02088238', 'basset', 0.032727525)]
# Actual: beagle Predicted: [('n02088364', 'beagle', 0.9799376), ('n02089867', 'Walker_hound', 0.01080759), ('n02089973', 'English_foxhound', 0.0034020045)]
# Actual: beagle Predicted: [('n04380533', 'table_lamp', 0.30365556), ('n03443371', 'goblet', 0.15427396), ('n03637318', 'lampshade', 0.08922887)]
# Actual: beagle Predicted: [('n02088364', 'beagle', 0.9918086), ('n02089867', 'Walker_hound', 0.0043680277), ('n02108000', 'EntleBucher', 0.00041516442)]
# Actual: beagle Predicted: [('n02088364', 'beagle', 0.9724459), ('n02089867', 'Walker_hound', 0.010789967), ('n02088238', 'basset', 0.009540718)]
# Actual: beagle Predicted: [('n02099712', 'Labrador_retriever', 0.874685), ('n02113186', 'Cardigan', 0.035106618), ('n02099601', 'golden_retriever', 0.027243016)]
# Actual: beagle Predicted: [('n02088238', 'basset', 0.7388216), ('n02089867', 'Walker_hound', 0.20212518), ('n02088364', 'beagle', 0.01776387)]
# Actual: beagle Predicted: [('n02088364', 'beagle', 0.99383175), ('n02089867', 'Walker_hound', 0.001422296), ('n02113023', 'Pembroke', 0.0011525654)]
# Actual: beagle Predicted: [('n02088364', 'beagle', 0.7911011), ('n02088238', 'basset', 0.09272263), ('n02089867', 'Walker_hound', 0.08259909)]
# Actual: beagle Predicted: [('n02088364', 'beagle', 0.44514462), ('n02088238', 'basset', 0.2719838), ('n02089867', 'Walker_hound', 0.22079296)]
# Actual: beagle Predicted: [('n02088238', 'basset', 0.5762677), ('n02089867', 'Walker_hound', 0.261105), ('n02088364', 'beagle', 0.10133166)]
# Actual: beagle Predicted: [('n02088364', 'beagle', 0.76131874), ('n02089867', 'Walker_hound', 0.12859072), ('n02089973', 'English_foxhound', 0.043379355)]
# Actual: beagle Predicted: [('n02088364', 'beagle', 0.9926838), ('n02089867', 'Walker_hound', 0.0027781744), ('n02089973', 'English_foxhound', 0.002740016)]
# Actual: beagle Predicted: [('n02088238', 'basset', 0.99472684), ('n02089867', 'Walker_hound', 0.0019025347), ('n02088364', 'beagle', 0.000969585)]
# Actual: Shih-Tzu Predicted: [('n02098413', 'Lhasa', 0.7079712), ('n02086240', 'Shih-Tzu', 0.29088628), ('n02097474', 'Tibetan_terrier', 0.0006356282)]
# Actual: Shih-Tzu Predicted: [('n02098413', 'Lhasa', 0.49707812), ('n02086240', 'Shih-Tzu', 0.31008524), ('n02085936', 'Maltese_dog', 0.13375576)]
# Actual: Shih-Tzu Predicted: [('n02086079', 'Pekinese', 0.9185219), ('n02085936', 'Maltese_dog', 0.036981396), ('n02086240', 'Shih-Tzu', 0.025288096)]
# Actual: Shih-Tzu Predicted: [('n02098105', 'soft-coated_wheaten_terrier', 0.40875977), ('n02105251', 'briard', 0.24429584), ('n02097474', 'Tibetan_terrier', 0.19092561)]
# Actual: Shih-Tzu Predicted: [('n02086240', 'Shih-Tzu', 0.7449338), ('n02098413', 'Lhasa', 0.23949888), ('n02097474', 'Tibetan_terrier', 0.010063835)]
# Actual: Shih-Tzu Predicted: [('n02110627', 'affenpinscher', 0.4187679), ('n02086240', 'Shih-Tzu', 0.3244269), ('n02094433', 'Yorkshire_terrier', 0.096521854)]
# Actual: Shih-Tzu Predicted: [('n02086240', 'Shih-Tzu', 0.85128444), ('n02098413', 'Lhasa', 0.070042074), ('n02086079', 'Pekinese', 0.04689804)]
# Actual: Shih-Tzu Predicted: [('n02086240', 'Shih-Tzu', 0.9862509), ('n02098413', 'Lhasa', 0.007033946), ('n02086079', 'Pekinese', 0.0050632213)]
# Actual: Shih-Tzu Predicted: [('n02086240', 'Shih-Tzu', 0.9809059), ('n02098413', 'Lhasa', 0.018839652), ('n02097474', 'Tibetan_terrier', 0.0001700622)]
# Actual: Shih-Tzu Predicted: [('n02086240', 'Shih-Tzu', 0.9920576), ('n02098413', 'Lhasa', 0.0079373075), ('n02086079', 'Pekinese', 2.4916383e-06)]
# Actual: Shih-Tzu Predicted: [('n02086240', 'Shih-Tzu', 0.9893387), ('n02098413', 'Lhasa', 0.0078814775), ('n02097474', 'Tibetan_terrier', 0.00085929455)]
# Actual: Shih-Tzu Predicted: [('n02086910', 'papillon', 0.3153814), ('n02808304', 'bath_towel', 0.24746828), ('n02087046', 'toy_terrier', 0.21368733)]
# Actual: Shih-Tzu Predicted: [('n02086240', 'Shih-Tzu', 0.9541173), ('n02098413', 'Lhasa', 0.019472402), ('n02097474', 'Tibetan_terrier', 0.015658442)]
# Actual: Shih-Tzu Predicted: [('n02086240', 'Shih-Tzu', 0.92592365), ('n02098413', 'Lhasa', 0.05861562), ('n02086079', 'Pekinese', 0.012214979)]
# Actual: Shih-Tzu Predicted: [('n02086240', 'Shih-Tzu', 0.97958964), ('n02098413', 'Lhasa', 0.017227504), ('n02086079', 'Pekinese', 0.0011115717)]
# Actual: Shih-Tzu Predicted: [('n02086240', 'Shih-Tzu', 0.73352945), ('n02098413', 'Lhasa', 0.1759185), ('n02096437', 'Dandie_Dinmont', 0.03324312)]
# Actual: dingo Predicted: [('n02115641', 'dingo', 0.9866176), ('n02105162', 'malinois', 0.0038920748), ('n02105412', 'kelpie', 0.0034117182)]
# Actual: dingo Predicted: [('n02115641', 'dingo', 0.9762799), ('n02115913', 'dhole', 0.0061611207), ('n02114548', 'white_wolf', 0.002642516)]
# Actual: dingo Predicted: [('n02115641', 'dingo', 0.8670297), ('n02110806', 'basenji', 0.053858336), ('n02091032', 'Italian_greyhound', 0.014459351)]
# Actual: dingo Predicted: [('n02115641', 'dingo', 0.7849192), ('n02115913', 'dhole', 0.1412932), ('n02113023', 'Pembroke', 0.036572255)]
# Actual: dingo Predicted: [('n02085620', 'Chihuahua', 0.18206239), ('n02115641', 'dingo', 0.110441424), ('n02123597', 'Siamese_cat', 0.06426277)]
# Actual: dingo Predicted: [('n02113023', 'Pembroke', 0.24959819), ('n02109961', 'Eskimo_dog', 0.15980287), ('n02110185', 'Siberian_husky', 0.08356467)]
# Actual: dingo Predicted: [('n02115641', 'dingo', 0.5542712), ('n02105162', 'malinois', 0.09128549), ('n02110806', 'basenji', 0.07263949)]
# Actual: dingo Predicted: [('n02115641', 'dingo', 0.6899349), ('n02114548', 'white_wolf', 0.16123821), ('n02125311', 'cougar', 0.069400094)]
# Actual: dingo Predicted: [('n02115641', 'dingo', 0.9812986), ('n02110185', 'Siberian_husky', 0.0032867254), ('n02106662', 'German_shepherd', 0.0019944676)]
# Actual: dingo Predicted: [('n02115641', 'dingo', 0.99555945), ('n02105162', 'malinois', 0.0017958315), ('n02105412', 'kelpie', 0.0012483915)]
# Actual: dingo Predicted: [('n02115641', 'dingo', 0.98643595), ('n02114855', 'coyote', 0.004812335), ('n02114712', 'red_wolf', 0.0027226226)]
# Actual: dingo Predicted: [('n02114712', 'red_wolf', 0.5072922), ('n02115641', 'dingo', 0.47158644), ('n02090379', 'redbone', 0.006722914)]
# Actual: dingo Predicted: [('n02115641', 'dingo', 0.9996991), ('n02114712', 'red_wolf', 0.00011608175), ('n02105412', 'kelpie', 4.7995323e-05)]
# Actual: dingo Predicted: [('n02105056', 'groenendael', 0.60771996), ('n02097130', 'giant_schnauzer', 0.16925819), ('n02097298', 'Scotch_terrier', 0.15147325)]
# Actual: dingo Predicted: [('n02115641', 'dingo', 0.98546576), ('n02115913', 'dhole', 0.0056694364), ('n02129165', 'lion', 0.0036545016)]
# Actual: dingo Predicted: [('n02115641', 'dingo', 0.49637908), ('n02110806', 'basenji', 0.28523308), ('n02105162', 'malinois', 0.0428831)]
# Actual: dingo Predicted: [('n02115641', 'dingo', 0.9840672), ('n02113186', 'Cardigan', 0.004195492), ('n02105412', 'kelpie', 0.00271766)]
# Actual: Old_English_sheepdog Predicted: [('n02105641', 'Old_English_sheepdog', 0.954948), ('n02097474', 'Tibetan_terrier', 0.010906827), ('n02091635', 'otterhound', 0.00915059)]
# Actual: Old_English_sheepdog Predicted: [('n02105641', 'Old_English_sheepdog', 0.9334102), ('n02105505', 'komondor', 0.02359919), ('n02096437', 'Dandie_Dinmont', 0.015348614)]
# Actual: Old_English_sheepdog Predicted: [('n02105641', 'Old_English_sheepdog', 0.9842705), ('n02091635', 'otterhound', 0.00796345), ('n02105505', 'komondor', 0.005115223)]
# Actual: Old_English_sheepdog Predicted: [('n02105641', 'Old_English_sheepdog', 0.999337), ('n02097474', 'Tibetan_terrier', 0.00042316222), ('n02095889', 'Sealyham_terrier', 7.5822805e-05)]
# Actual: Old_English_sheepdog Predicted: [('n02105641', 'Old_English_sheepdog', 0.99628204), ('n02105505', 'komondor', 0.0032203973), ('n02091635', 'otterhound', 0.0002981181)]
# Actual: Old_English_sheepdog Predicted: [('n02105641', 'Old_English_sheepdog', 0.92874265), ('n02097474', 'Tibetan_terrier', 0.04994422), ('n02096437', 'Dandie_Dinmont', 0.007206676)]
# Actual: Old_English_sheepdog Predicted: [('n02105641', 'Old_English_sheepdog', 0.95168245), ('n02105505', 'komondor', 0.047258735), ('n02091635', 'otterhound', 0.00062685675)]
# Actual: Old_English_sheepdog Predicted: [('n02105641', 'Old_English_sheepdog', 0.9247757), ('n02091635', 'otterhound', 0.059173927), ('n02106382', 'Bouvier_des_Flandres', 0.0077400133)]
# Actual: Old_English_sheepdog Predicted: [('n02105641', 'Old_English_sheepdog', 0.7161041), ('n02086240', 'Shih-Tzu', 0.13779363), ('n02097474', 'Tibetan_terrier', 0.09560765)]
# Actual: Old_English_sheepdog Predicted: [('n02105641', 'Old_English_sheepdog', 0.9853591), ('n02105505', 'komondor', 0.00702082), ('n02098105', 'soft-coated_wheaten_terrier', 0.002416152)]
# Actual: Old_English_sheepdog Predicted: [('n02105641', 'Old_English_sheepdog', 0.99787986), ('n02101556', 'clumber', 0.00050728297), ('n02105505', 'komondor', 0.00043985373)]
# Actual: Old_English_sheepdog Predicted: [('n02105641', 'Old_English_sheepdog', 0.7359271), ('n02111500', 'Great_Pyrenees', 0.10716161), ('n02090721', 'Irish_wolfhound', 0.06559416)]
# Actual: Old_English_sheepdog Predicted: [('n02105641', 'Old_English_sheepdog', 0.9999378), ('n02106382', 'Bouvier_des_Flandres', 2.4437246e-05), ('n02091635', 'otterhound', 1.6245433e-05)]
# Actual: Australian_terrier Predicted: [('n02113023', 'Pembroke', 0.24552186), ('n02096294', 'Australian_terrier', 0.16598476), ('n02094258', 'Norwich_terrier', 0.10798981)]
# Actual: Australian_terrier Predicted: [('n02096294', 'Australian_terrier', 0.26857662), ('n02097047', 'miniature_schnauzer', 0.12881127), ('n02096177', 'cairn', 0.113627754)]
# Actual: Australian_terrier Predicted: [('n02096294', 'Australian_terrier', 0.6465806), ('n02094258', 'Norwich_terrier', 0.25188527), ('n02115913', 'dhole', 0.043892317)]
# Actual: Australian_terrier Predicted: [('n02097047', 'miniature_schnauzer', 0.5276634), ('n02093754', 'Border_terrier', 0.18297295), ('n02095570', 'Lakeland_terrier', 0.07821243)]
# Actual: Australian_terrier Predicted: [('n02096294', 'Australian_terrier', 0.9385118), ('n02094258', 'Norwich_terrier', 0.04831245), ('n02094114', 'Norfolk_terrier', 0.0057139485)]
# Actual: Australian_terrier Predicted: [('n02094114', 'Norfolk_terrier', 0.8134787), ('n02096437', 'Dandie_Dinmont', 0.0972678), ('n02096294', 'Australian_terrier', 0.027997099)]
# Actual: Australian_terrier Predicted: [('n02093991', 'Irish_terrier', 0.8483345), ('n02096294', 'Australian_terrier', 0.12588124), ('n02096177', 'cairn', 0.0077538127)]
# Actual: Australian_terrier Predicted: [('n02093991', 'Irish_terrier', 0.72946316), ('n02096294', 'Australian_terrier', 0.12141069), ('n02100877', 'Irish_setter', 0.040500056)]
# Actual: Australian_terrier Predicted: [('n02096294', 'Australian_terrier', 0.5266776), ('n02097658', 'silky_terrier', 0.31041545), ('n02085936', 'Maltese_dog', 0.05493065)]
# Actual: Australian_terrier Predicted: [('n02096294', 'Australian_terrier', 0.5979347), ('n02094433', 'Yorkshire_terrier', 0.17843756), ('n02094258', 'Norwich_terrier', 0.1335247)]
# Actual: Australian_terrier Predicted: [('n02106166', 'Border_collie', 0.28985864), ('n02097474', 'Tibetan_terrier', 0.15664701), ('n02086910', 'papillon', 0.084431015)]
# Actual: Australian_terrier Predicted: [('n02099601', 'golden_retriever', 0.41631114), ('n02108551', 'Tibetan_mastiff', 0.25016895), ('n02111129', 'Leonberg', 0.07865492)]
# Actual: Australian_terrier Predicted: [('n02096294', 'Australian_terrier', 0.68508494), ('n02094258', 'Norwich_terrier', 0.23512363), ('n02094433', 'Yorkshire_terrier', 0.032936428)]
# Actual: Australian_terrier Predicted: [('n02096294', 'Australian_terrier', 0.9585844), ('n02094258', 'Norwich_terrier', 0.018233512), ('n02096177', 'cairn', 0.010044001)]
# Actual: Australian_terrier Predicted: [('n02094258', 'Norwich_terrier', 0.77698576), ('n02096294', 'Australian_terrier', 0.20188516), ('n02094114', 'Norfolk_terrier', 0.010736113)]
# Actual: Australian_terrier Predicted: [('n02093991', 'Irish_terrier', 0.9187544), ('n02094114', 'Norfolk_terrier', 0.038443174), ('n02096294', 'Australian_terrier', 0.036805205)]
# Actual: Australian_terrier Predicted: [('n02096294', 'Australian_terrier', 0.98033994), ('n02094433', 'Yorkshire_terrier', 0.009959442), ('n02097658', 'silky_terrier', 0.0057106153)]
# Actual: Australian_terrier Predicted: [('n02096294', 'Australian_terrier', 0.50389063), ('n02094258', 'Norwich_terrier', 0.35456923), ('n02093991', 'Irish_terrier', 0.08318078)]

# %%
asdf = tmp[1][0][0]
print(asdf)
# Out:
# n02087394

# %% [markdown]
# ## TODO8: TOP-1 정확도를 직접 계산해봅시다.

# %%
correct = 0 
incorrect = 0
tmp = decode_predictions(preds, top=1) # TODO

for i in range(len(preds)):
  # TODO
  if idx2label[test_labels[i]] == tmp[i][0][1]:
    correct = correct + 1
  else:
    incorrect = incorrect + 1
 
print(correct , incorrect)
acc = correct/ 162

acc = "{:.2%}".format(acc)
print('Accuracy:', acc)
# Out:
# 110 52
# Accuracy: 67.90%
